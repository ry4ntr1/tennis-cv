# %%
# !nvidia-smi
# Out:
# Sun Jun 23 19:28:03 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0              44W / 400W |      5MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install roboflow torch torchvision torchaudio ultralytics python-dotenv --quiet

# %%
import os
import torch
from roboflow import Roboflow
from ultralytics import YOLO
from pathlib import Path
from google.colab import drive
from dotenv import load_dotenv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ROOT_DIR = Path('/content/drive/MyDrive/tennis-cv/').resolve()

# %%
TRAINING_DIR = ROOT_DIR / 'training'
MODELS_DIR = ROOT_DIR / 'models'

DATA_DIR = ROOT_DIR / 'data'
TENNIS_BALL_DIR = DATA_DIR / 'tennis_ball'
KEYPOINTS_DIR = DATA_DIR / 'keypoints'

DATA_DIR.mkdir(parents=True, exist_ok=True)
MODELS_DIR.mkdir(parents=True, exist_ok=True)

TRAINING_DIR.mkdir(parents=True, exist_ok=True)
TENNIS_BALL_DIR.mkdir(parents=True, exist_ok=True)
KEYPOINTS_DIR.mkdir(parents=True, exist_ok=True)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
if not any(TENNIS_BALL_DIR.iterdir()):
    print(f"No data found in {TENNIS_BALL_DIR}, downloading dataset...")
    load_dotenv(ROOT_DIR / '.env')
    rf = Roboflow(api_key=os.getenv("ROBOFLOW_API_KEY"))
    project = rf.workspace("ry4ntr1").project("tennis-ball-m7zvw")
    version = project.version(3)
    dataset = version.download(model_format="yolov8", location=str(TENNIS_BALL_DIR), overwrite=True)
else:
    print(f"Data already present in {TENNIS_BALL_DIR}, no need to download.")
# Out:
# No data found in /content/drive/MyDrive/tennis-cv/data/tennis_ball, downloading dataset...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.40, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in /content/drive/MyDrive/tennis-cv/data/tennis_ball to yolov8:: 100%|██████████| 164138/164138 [00:19<00:00, 8395.84it/s]
# Extracting Dataset Version Zip to /content/drive/MyDrive/tennis-cv/data/tennis_ball in yolov8:: 100%|██████████| 6785/6785 [01:09<00:00, 98.27it/s]

# %%
os.chdir(str(ROOT_DIR))

# %%
if os.path.exists(str(MODELS_DIR / 'best.pt')):
    trained_model = YOLO(str(MODELS_DIR / 'best.pt'))
else:
    model = YOLO('yolov8n.pt')
    model.train(data=str(TENNIS_BALL_DIR / 'data.yaml'), save=True, save_dir=MODELS_DIR, save_period=10, verbose=True)
# Out:
# New https://pypi.org/project/ultralytics/8.2.41 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.40 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/drive/MyDrive/tennis-cv/data/tennis_ball/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=10, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/tennis-cv/data/tennis_ball/train/labels.cache... 2371 images, 10 backgrounds, 0 corrupt: 100%|██████████| 2371/2371 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/drive/MyDrive/tennis-cv/data/tennis_ball/train/images/scene57901_jpg.rf.6511105d25878ddf4e7d66b7b62ce3f1.jpg: 4 duplicate labels removed
# train: WARNING ⚠️ /content/drive/MyDrive/tennis-cv/data/tennis_ball/train/images/scene57901_jpg.rf.afaa87d778ed1646b6b88870dc8e70f5.jpg: 4 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-25-c857cefec99c> in <cell line: 1>()
#       3 else:
#       4     model = YOLO('yolov8n.pt')
# ----> 5     model.train(data=str(TENNIS_BALL_DIR / 'data.yaml'), save=True, save_dir=MODELS_DIR, save_period=10, verbose=True)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     648
#     649         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 650         self.trainer.train()
#     651         # Update model and cfg after training
#     652         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in train(self)
#     197
#     198         else:
# --> 199             self._do_train(world_size)
#     200
#     201     def _setup_scheduler(self):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     316         if world_size > 1:
#     317             self._setup_ddp(world_size)
# --> 318         self._setup_train(world_size)
#     319
#     320         nb = len(self.train_loader)  # number of batches
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py in _setup_train(self, world_size)
#     283         if RANK in {-1, 0}:
#     284             # Note: When training DOTA dataset, double batch size could get OOM on images with >2000 objects.
# --> 285             self.test_loader = self.get_dataloader(
#     286                 self.testset, batch_size=batch_size if self.args.task == "obb" else batch_size * 2, rank=-1, mode="val"
#     287             )
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/detect/train.py in get_dataloader(self, dataset_path, batch_size, rank, mode)
#      47         assert mode in {"train", "val"}, f"Mode must be 'train' or 'val', not {mode}."
#      48         with torch_distributed_zero_first(rank):  # init dataset *.cache only once if DDP
# ---> 49             dataset = self.build_dataset(dataset_path, mode, batch_size)
#      50         shuffle = mode == "train"
#      51         if getattr(dataset, "rect", False) and shuffle:
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/detect/train.py in build_dataset(self, img_path, mode, batch)
#      41         """
#      42         gs = max(int(de_parallel(self.model).stride.max() if self.model else 0), 32)
# ---> 43         return build_yolo_dataset(self.args, img_path, batch, self.data, mode=mode, rect=mode == "val", stride=gs)
#      44
#      45     def get_dataloader(self, dataset_path, batch_size=16, rank=0, mode="train"):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/data/build.py in build_yolo_dataset(cfg, img_path, batch, data, mode, rect, stride, multi_modal)
#      85     """Build YOLO Dataset."""
#      86     dataset = YOLOMultiModalDataset if multi_modal else YOLODataset
# ---> 87     return dataset(
#      88         img_path=img_path,
#      89         imgsz=cfg.imgsz,
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/data/dataset.py in __init__(self, data, task, *args, **kwargs)
#      62         self.data = data
#      63         assert not (self.use_segments and self.use_keypoints), "Can not use both segments and keypoints."
# ---> 64         super().__init__(*args, **kwargs)
#      65
#      66     def cache_labels(self, path=Path("./labels.cache")):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/data/base.py in __init__(self, img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls, classes, fraction)
#      72         self.fraction = fraction
#      73         self.im_files = self.get_img_files(self.img_path)
# ---> 74         self.labels = self.get_labels()
#      75         self.update_labels(include_class=classes)  # single_cls and include_class
#      76         self.ni = len(self.labels)  # number of images
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/data/dataset.py in get_labels(self)
#     138             cache, exists = load_dataset_cache_file(cache_path), True  # attempt to load a *.cache file
#     139             assert cache["version"] == DATASET_CACHE_VERSION  # matches current version
# --> 140             assert cache["hash"] == get_hash(self.label_files + self.im_files)  # identical hash
#     141         except (FileNotFoundError, AssertionError, AttributeError):
#     142             cache, exists = self.cache_labels(cache_path), False  # run cache ops
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/data/utils.py in get_hash(paths)
#      51 def get_hash(paths):
#      52     """Returns a single hash value of a list of paths (files or dirs)."""
# ---> 53     size = sum(os.path.getsize(p) for p in paths if os.path.exists(p))  # sizes
#      54     h = hashlib.sha256(str(size).encode())  # hash sizes
#      55     h.update("".join(paths).encode())  # hash paths
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/data/utils.py in <genexpr>(.0)
#      51 def get_hash(paths):
#      52     """Returns a single hash value of a list of paths (files or dirs)."""
# ---> 53     size = sum(os.path.getsize(p) for p in paths if os.path.exists(p))  # sizes
#      54     h = hashlib.sha256(str(size).encode())  # hash sizes
#      55     h.update("".join(paths).encode())  # hash paths
#
# /usr/lib/python3.10/genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#      21         return False
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/signal_handling.py in handler(signum, frame)
#      64         # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65         # Python can still get and update the process status successfully.
# ---> 66         _error_if_any_worker_fails()
#      67         if previous_handler is not None:
#      68             assert callable(previous_handler)
#
# SystemError: <built-in function _error_if_any_worker_fails> returned a result with an exception set

# %%
trained_model = YOLO('/content/runs/detect/train/weights/best.pt').to(device)
# trained_model = YOLO(str(MODELS_DIR / 'best.pt')).to(device)
sample_image_path = ROOT_DIR / 'sample_data/sample.png'
sample_vid_path = ROOT_DIR / 'sample_data/sample.mp4'

# %% [markdown]
# ## Prediction On Sample Data

# %%
trained_model.predict(task='detect', source=str(sample_image_path), save=True, save_dir=str('/content/runs/predict'))
# Out:
# image 1/1 /content/drive/MyDrive/tennis-cv/sample_data/sample.png: 320x640 2 playerss, 1 tennis_ball, 11.3ms
# Speed: 3.2ms preprocess, 11.3ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 24,  23,  38],
#          [ 24,  23,  38],
#          [ 24,  23,  38],
#          ...,
#          [ 30,  24,  42],
#          [ 30,  24,  42],
#          [ 20,  20,  20]],
#
#         [[ 24,  23,  38],
#          [ 24,  23,  38],
#          [ 24,  23,  38],
#          ...,
#          [ 31,  24,  42],
#          [ 31,  24,  42],
#          [ 20,  20,  20]],
#
#         [[ 24,  23,  38],
#          [ 24,  23,  38],
#          [ 24,  23,  38],
#          ...,
#          [ 31,  24,  42],
#          [ 31,  24,  42],
#          [ 20,  20,  20]],
#
#         ...,
#
#         [[187, 153, 113],
#          [187, 153, 113],
#          [187, 153, 113],
#          ...,
#          [178, 145, 107],
#          [178, 145, 107],
#          [  0,   0,   0]],
#
#         [[187, 153, 113],
#          [187, 153, 113],
#          [187, 153, 113],
#          ...,
#          [178, 145, 107],
#          [178, 145, 107],
#          [  0,   0,   0]],
#
#         [[187, 153, 113],
#          [187, 153, 113],
#          [187, 153, 113],
#          ...,
#          [178, 145, 107],
#          [178, 145, 107],
#          [  0,   0,   0]]], dtype=uint8)
#  orig_shape: (1204, 2471)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.png'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.240346908569336, 'inference': 11.342287063598633, 'postprocess': 2.173900604248047}]

# %%
trained_model.predict(task='detect', source=str(sample_vid_path), save=True, save_dir=str('/content/runs/predict'))
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 121.1ms
# video 1/1 (frame 2/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.5ms
# video 1/1 (frame 3/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 2 tennis_balls, 7.8ms
# video 1/1 (frame 4/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 5/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 6/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 7/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.3ms
# video 1/1 (frame 8/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 9/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 10/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 11/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 12/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 13/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 14/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 15/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 16/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 17/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 18/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 19/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 20/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 21/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 22/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 23/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.5ms
# video 1/1 (frame 24/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 25/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.6ms
# video 1/1 (frame 26/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 27/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 28/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 2 tennis_balls, 8.1ms
# video 1/1 (frame 29/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.7ms
# video 1/1 (frame 30/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.5ms
# video 1/1 (frame 31/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.2ms
# video 1/1 (frame 32/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 33/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.7ms
# video 1/1 (frame 34/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 35/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 36/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 37/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.7ms
# video 1/1 (frame 38/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 39/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 40/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.3ms
# video 1/1 (frame 41/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.5ms
# video 1/1 (frame 42/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 43/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.5ms
# video 1/1 (frame 44/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 45/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 2 tennis_balls, 7.8ms
# video 1/1 (frame 46/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.7ms
# video 1/1 (frame 47/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 48/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 49/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.2ms
# video 1/1 (frame 50/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 51/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 52/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 53/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.5ms
# video 1/1 (frame 54/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.5ms
# video 1/1 (frame 55/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.7ms
# video 1/1 (frame 56/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 57/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 58/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.5ms
# video 1/1 (frame 59/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.7ms
# video 1/1 (frame 60/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.6ms
# video 1/1 (frame 61/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 62/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 63/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.2ms
# video 1/1 (frame 64/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 65/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 66/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 67/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.9ms
# video 1/1 (frame 68/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.5ms
# video 1/1 (frame 69/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 2 tennis_balls, 7.9ms
# video 1/1 (frame 70/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 71/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 72/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 73/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.4ms
# video 1/1 (frame 74/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.7ms
# video 1/1 (frame 75/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.6ms
# video 1/1 (frame 76/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 77/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 2 tennis_balls, 9.3ms
# video 1/1 (frame 78/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 79/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 80/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 81/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 82/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 83/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.3ms
# video 1/1 (frame 84/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 85/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 2 tennis_balls, 8.0ms
# video 1/1 (frame 86/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 87/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 9.8ms
# video 1/1 (frame 88/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.8ms
# video 1/1 (frame 89/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.4ms
# video 1/1 (frame 90/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 91/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.3ms
# video 1/1 (frame 92/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 93/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 94/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 95/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.2ms
# video 1/1 (frame 96/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 97/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 2 tennis_balls, 7.8ms
# video 1/1 (frame 98/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 99/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 2 tennis_balls, 7.9ms
# video 1/1 (frame 100/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.7ms
# video 1/1 (frame 101/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 102/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.4ms
# video 1/1 (frame 103/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.2ms
# video 1/1 (frame 104/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 9.8ms
# video 1/1 (frame 105/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.7ms
# video 1/1 (frame 106/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.0ms
# video 1/1 (frame 107/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 12.0ms
# video 1/1 (frame 108/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.6ms
# video 1/1 (frame 109/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.7ms
# video 1/1 (frame 110/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 111/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.6ms
# video 1/1 (frame 112/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 113/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.7ms
# video 1/1 (frame 114/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.4ms
# video 1/1 (frame 115/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 9.0ms
# video 1/1 (frame 116/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 10.3ms
# video 1/1 (frame 117/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 118/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.3ms
# video 1/1 (frame 119/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 120/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 121/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 122/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 123/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 124/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 125/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 126/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 127/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.2ms
# video 1/1 (frame 128/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 129/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 130/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.7ms
# video 1/1 (frame 131/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 132/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.1ms
# video 1/1 (frame 133/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.3ms
# video 1/1 (frame 134/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.0ms
# video 1/1 (frame 135/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 136/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.0ms
# video 1/1 (frame 137/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 138/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.1ms
# video 1/1 (frame 139/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 140/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 141/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 142/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 9.5ms
# video 1/1 (frame 143/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 144/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.2ms
# video 1/1 (frame 145/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 146/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.7ms
# video 1/1 (frame 147/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 7.9ms
# video 1/1 (frame 148/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 3 tennis_balls, 7.8ms
# video 1/1 (frame 149/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 150/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 151/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.6ms
# video 1/1 (frame 152/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 9.1ms
# video 1/1 (frame 153/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 9.3ms
# video 1/1 (frame 154/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 7.9ms
# video 1/1 (frame 155/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 8.0ms
# video 1/1 (frame 156/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 8.0ms
# video 1/1 (frame 157/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 8.0ms
# video 1/1 (frame 158/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 8.1ms
# video 1/1 (frame 159/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.4ms
# video 1/1 (frame 160/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 161/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 162/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 163/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 9.6ms
# video 1/1 (frame 164/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.6ms
# video 1/1 (frame 165/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.4ms
# video 1/1 (frame 166/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 167/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 168/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 169/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 170/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.5ms
# video 1/1 (frame 171/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.2ms
# video 1/1 (frame 172/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 8.0ms
# video 1/1 (frame 173/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 10.3ms
# video 1/1 (frame 174/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 9.0ms
# video 1/1 (frame 175/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 8.0ms
# video 1/1 (frame 176/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 177/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 178/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 179/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.5ms
# video 1/1 (frame 180/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.0ms
# video 1/1 (frame 181/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 182/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.6ms
# video 1/1 (frame 183/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 8.8ms
# video 1/1 (frame 184/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.8ms
# video 1/1 (frame 185/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 9.1ms
# video 1/1 (frame 186/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 187/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 188/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 2 playerss, 1 tennis_ball, 9.0ms
# video 1/1 (frame 189/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 190/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.0ms
# video 1/1 (frame 191/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.1ms
# video 1/1 (frame 192/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 193/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 194/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 195/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.8ms
# video 1/1 (frame 196/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.7ms
# video 1/1 (frame 197/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.2ms
# video 1/1 (frame 198/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 7.9ms
# video 1/1 (frame 199/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 7.9ms
# video 1/1 (frame 200/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.5ms
# video 1/1 (frame 201/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 9.2ms
# video 1/1 (frame 202/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.3ms
# video 1/1 (frame 203/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.3ms
# video 1/1 (frame 204/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 9.0ms
# video 1/1 (frame 205/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.5ms
# video 1/1 (frame 206/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.1ms
# video 1/1 (frame 207/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 8.5ms
# video 1/1 (frame 208/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.3ms
# video 1/1 (frame 209/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.1ms
# video 1/1 (frame 210/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.2ms
# video 1/1 (frame 211/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.2ms
# video 1/1 (frame 212/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.4ms
# video 1/1 (frame 213/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.4ms
# video 1/1 (frame 214/214) /content/drive/MyDrive/tennis-cv/sample_data/sample.mp4: 384x640 1 official, 3 playerss, 1 tennis_ball, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 20,  12,  25],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 20,  12,  25],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 21,  13,  28],
#          [ 21,  13,  28],
#          [ 20,  11,  29],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.3838748931884766, 'inference': 121.08469009399414, 'postprocess': 2.038240432739258},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 20,  12,  25],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 20,  12,  25],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 21,  13,  28],
#          [ 21,  13,  28],
#          [ 20,  11,  29],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.2678375244140625, 'inference': 8.547544479370117, 'postprocess': 1.524209976196289},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 20,  12,  25],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 20,  12,  25],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 21,  13,  28],
#          [ 21,  13,  28],
#          [ 20,  11,  29],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.1975040435791016, 'inference': 7.819890975952148, 'postprocess': 1.4367103576660156},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 20,  12,  25],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 20,  12,  25],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 21,  13,  28],
#          [ 21,  13,  28],
#          [ 20,  11,  29],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.2573471069335938, 'inference': 7.8983306884765625, 'postprocess': 1.5330314636230469},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 20,  12,  25],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 20,  12,  25],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 21,  13,  28],
#          [ 21,  13,  28],
#          [ 20,  11,  29],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.2041072845458984, 'inference': 7.933616638183594, 'postprocess': 1.5077590942382812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 20,  12,  25],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 20,  12,  25],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 21,  13,  28],
#          [ 21,  13,  28],
#          [ 20,  11,  29],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.230405807495117, 'inference': 7.806062698364258, 'postprocess': 1.5101432800292969},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 20,  12,  25],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 20,  12,  25],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 21,  13,  28],
#          [ 21,  13,  28],
#          [ 20,  11,  29],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.215147018432617, 'inference': 8.288860321044922, 'postprocess': 1.4543533325195312},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 19,  11,  24],
#          [ 18,  10,  23],
#          [ 17,   9,  22],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 19,  11,  24],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 20,  12,  27],
#          [ 20,  12,  27],
#          [ 19,  10,  28],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.176523208618164, 'inference': 7.914543151855469, 'postprocess': 1.5087127685546875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 19,  11,  24],
#          [ 18,  10,  23],
#          [ 17,   9,  22],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 19,  11,  24],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 20,  12,  27],
#          [ 20,  12,  27],
#          [ 19,  10,  28],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.249002456665039, 'inference': 8.1024169921875, 'postprocess': 1.5163421630859375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 19,  11,  24],
#          [ 18,  10,  23],
#          [ 17,   9,  22],
#          ...,
#          [ 13,   0,  36],
#          [ 13,   0,  36],
#          [ 15,   2,  38]],
#
#         [[ 19,  11,  24],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 22,   9,  45],
#          [ 23,  10,  46]],
#
#         [[ 20,  11,  29],
#          [ 20,  11,  29],
#          [ 19,  10,  28],
#          ...,
#          [ 32,  18,  57],
#          [ 34,  17,  57],
#          [ 35,  18,  58]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.383159637451172, 'inference': 7.946968078613281, 'postprocess': 1.4998912811279297},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 19,  11,  24],
#          [ 18,  10,  23],
#          [ 17,   9,  22],
#          ...,
#          [ 13,   0,  36],
#          [ 13,   0,  36],
#          [ 15,   2,  38]],
#
#         [[ 19,  11,  24],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 22,   9,  45],
#          [ 23,  10,  46]],
#
#         [[ 20,  11,  29],
#          [ 20,  11,  29],
#          [ 19,  10,  28],
#          ...,
#          [ 32,  18,  57],
#          [ 34,  17,  57],
#          [ 35,  18,  58]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.131223678588867, 'inference': 7.598161697387695, 'postprocess': 1.4166831970214844},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 19,  11,  24],
#          [ 18,  10,  23],
#          [ 17,   9,  22],
#          ...,
#          [ 10,   0,  36],
#          [ 10,   0,  36],
#          [ 12,   2,  38]],
#
#         [[ 19,  11,  24],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 19,   9,  45],
#          [ 19,   9,  45],
#          [ 20,  10,  46]],
#
#         [[ 20,  11,  29],
#          [ 20,  11,  29],
#          [ 19,  10,  28],
#          ...,
#          [ 29,  18,  57],
#          [ 32,  18,  57],
#          [ 33,  19,  58]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.2735595703125, 'inference': 8.01396369934082, 'postprocess': 1.5151500701904297},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 19,  11,  24],
#          [ 18,  10,  23],
#          [ 17,   9,  22],
#          ...,
#          [ 10,   0,  36],
#          [ 10,   0,  36],
#          [ 12,   2,  38]],
#
#         [[ 19,  11,  24],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 19,   9,  45],
#          [ 19,   9,  45],
#          [ 20,  10,  46]],
#
#         [[ 20,  11,  29],
#          [ 20,  11,  29],
#          [ 19,  10,  28],
#          ...,
#          [ 29,  18,  57],
#          [ 32,  18,  57],
#          [ 33,  19,  58]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
# ...
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.3173561096191406, 'inference': 8.970260620117188, 'postprocess': 2.072572708129883},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 17,  12,  24],
#          [ 15,  10,  22],
#          [ 11,   6,  20],
#          ...,
#          [  7,   0,  37],
#          [  9,   0,  37],
#          [ 12,   1,  40]],
#
#         [[ 18,  13,  25],
#          [ 15,  10,  22],
#          [ 10,   5,  19],
#          ...,
#          [ 16,   5,  46],
#          [ 20,   9,  48],
#          [ 21,  10,  49]],
#
#         [[ 20,  14,  31],
#          [ 19,  13,  30],
#          [ 17,  10,  29],
#          ...,
#          [ 30,  19,  58],
#          [ 34,  21,  57],
#          [ 37,  24,  60]],
#
#         ...,
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.361297607421875, 'inference': 8.490800857543945, 'postprocess': 1.5149116516113281},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 17,  12,  24],
#          [ 15,  10,  22],
#          [ 11,   6,  20],
#          ...,
#          [  7,   0,  38],
#          [  9,   0,  39],
#          [ 12,   1,  42]],
#
#         [[ 18,  13,  25],
#          [ 15,  10,  22],
#          [ 10,   5,  19],
#          ...,
#          [ 16,   4,  47],
#          [ 20,   9,  50],
#          [ 21,  10,  51]],
#
#         [[ 20,  14,  31],
#          [ 19,  13,  30],
#          [ 17,  10,  29],
#          ...,
#          [ 30,  19,  60],
#          [ 34,  20,  59],
#          [ 37,  23,  62]],
#
#         ...,
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.2535324096679688, 'inference': 8.119344711303711, 'postprocess': 1.5282630920410156},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 17,  12,  24],
#          [ 15,  10,  22],
#          [ 11,   6,  20],
#          ...,
#          [  7,   0,  38],
#          [  9,   0,  39],
#          [ 12,   1,  42]],
#
#         [[ 18,  13,  25],
#          [ 15,  10,  22],
#          [ 10,   5,  19],
#          ...,
#          [ 16,   4,  47],
#          [ 20,   9,  50],
#          [ 21,  10,  51]],
#
#         [[ 20,  14,  31],
#          [ 19,  13,  30],
#          [ 17,  10,  29],
#          ...,
#          [ 30,  19,  60],
#          [ 34,  20,  59],
#          [ 37,  23,  62]],
#
#         ...,
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [173, 142, 104],
#          [173, 142, 104],
#          [173, 142, 104]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.607107162475586, 'inference': 8.454561233520508, 'postprocess': 1.5642642974853516},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 16,  11,  23],
#          [ 16,  11,  23],
#          [ 12,   7,  21],
#          ...,
#          [  7,   0,  38],
#          [  9,   0,  39],
#          [ 12,   1,  42]],
#
#         [[ 17,  12,  24],
#          [ 16,  11,  23],
#          [ 11,   6,  20],
#          ...,
#          [ 16,   4,  47],
#          [ 20,   9,  50],
#          [ 21,  10,  51]],
#
#         [[ 20,  14,  31],
#          [ 20,  14,  31],
#          [ 18,  11,  30],
#          ...,
#          [ 30,  19,  60],
#          [ 34,  20,  59],
#          [ 37,  23,  62]],
#
#         ...,
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3903846740722656, 'inference': 8.26716423034668, 'postprocess': 1.573801040649414},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 16,  11,  23],
#          [ 16,  11,  23],
#          [ 12,   7,  21],
#          ...,
#          [  7,   0,  38],
#          [  9,   0,  39],
#          [ 12,   1,  42]],
#
#         [[ 17,  12,  24],
#          [ 16,  11,  23],
#          [ 11,   6,  20],
#          ...,
#          [ 16,   4,  47],
#          [ 20,   9,  50],
#          [ 21,  10,  51]],
#
#         [[ 20,  14,  31],
#          [ 20,  14,  31],
#          [ 18,  11,  30],
#          ...,
#          [ 30,  19,  60],
#          [ 34,  20,  59],
#          [ 37,  23,  62]],
#
#         ...,
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 150, 110],
#          [180, 150, 110],
#          [180, 150, 110],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3272037506103516, 'inference': 8.091449737548828, 'postprocess': 1.5230178833007812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 17,  12,  24],
#          [ 17,  12,  24],
#          [ 13,   8,  22],
#          ...,
#          [  7,   0,  38],
#          [  9,   0,  39],
#          [ 12,   1,  42]],
#
#         [[ 17,  12,  24],
#          [ 16,  11,  23],
#          [ 11,   6,  20],
#          ...,
#          [ 16,   4,  47],
#          [ 20,   9,  50],
#          [ 21,  10,  51]],
#
#         [[ 20,  14,  31],
#          [ 20,  14,  31],
#          [ 18,  11,  30],
#          ...,
#          [ 30,  19,  60],
#          [ 34,  20,  59],
#          [ 37,  23,  62]],
#
#         ...,
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3598670959472656, 'inference': 8.229494094848633, 'postprocess': 1.5652179718017578},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 19,  14,  28],
#          [ 17,  12,  26],
#          [ 12,   7,  21],
#          ...,
#          [  7,   0,  38],
#          [  9,   0,  39],
#          [ 12,   1,  42]],
#
#         [[ 18,  13,  27],
#          [ 16,  11,  25],
#          [ 10,   5,  19],
#          ...,
#          [ 16,   4,  47],
#          [ 20,   9,  50],
#          [ 21,  10,  51]],
#
#         [[ 19,  12,  31],
#          [ 19,  12,  31],
#          [ 17,  10,  29],
#          ...,
#          [ 30,  19,  60],
#          [ 34,  20,  59],
#          [ 37,  23,  62]],
#
#         ...,
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.399921417236328, 'inference': 8.211851119995117, 'postprocess': 1.5037059783935547},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 21,  13,  28],
#          [ 19,  11,  26],
#          [ 14,   6,  21],
#          ...,
#          [  7,   0,  38],
#          [  9,   0,  39],
#          [ 12,   1,  42]],
#
#         [[ 20,  12,  27],
#          [ 18,  10,  25],
#          [ 12,   4,  19],
#          ...,
#          [ 16,   4,  47],
#          [ 20,   9,  50],
#          [ 21,  10,  51]],
#
#         [[ 21,  11,  31],
#          [ 21,  11,  31],
#          [ 19,   9,  29],
#          ...,
#          [ 30,  19,  60],
#          [ 34,  20,  59],
#          [ 37,  23,  62]],
#
#         ...,
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.280712127685547, 'inference': 8.39090347290039, 'postprocess': 1.5566349029541016},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 21,  13,  28],
#          [ 19,  11,  26],
#          [ 14,   6,  21],
#          ...,
#          [  7,   0,  40],
#          [  9,   0,  40],
#          [ 12,   0,  43]],
#
#         [[ 20,  12,  27],
#          [ 18,  10,  25],
#          [ 12,   4,  19],
#          ...,
#          [ 16,   3,  49],
#          [ 20,   8,  51],
#          [ 21,   9,  52]],
#
#         [[ 21,  11,  31],
#          [ 21,  11,  31],
#          [ 19,   9,  29],
#          ...,
#          [ 30,  18,  61],
#          [ 34,  20,  61],
#          [ 37,  23,  64]],
#
#         ...,
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.3412704467773438, 'inference': 8.353471755981445, 'postprocess': 1.5823841094970703},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'official', 1: 'players', 2: 'tennis_ball'}
#  obb: None
#  orig_img: array([[[ 21,  13,  28],
#          [ 19,  11,  26],
#          [ 14,   6,  21],
#          ...,
#          [  7,   0,  41],
#          [  9,   0,  42],
#          [ 12,   0,  45]],
#
#         [[ 20,  12,  27],
#          [ 18,  10,  25],
#          [ 12,   4,  19],
#          ...,
#          [ 16,   2,  50],
#          [ 20,   7,  53],
#          [ 21,   8,  54]],
#
#         [[ 21,  11,  31],
#          [ 21,  11,  31],
#          [ 19,   9,  29],
#          ...,
#          [ 30,  17,  63],
#          [ 34,  19,  62],
#          [ 37,  22,  65]],
#
#         ...,
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[180, 149, 111],
#          [180, 149, 111],
#          [180, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/content/drive/MyDrive/tennis-cv/sample_data/sample.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.4847984313964844, 'inference': 8.562803268432617, 'postprocess': 1.5044212341308594}]

# %% [markdown]
# ## Export To Core ML

# %%
model.export(format='coreml', save=True)
